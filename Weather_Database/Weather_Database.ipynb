# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
from config import g_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size =2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pasvalys
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | talnakh
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | teguldet
# Processing Record 8 of Set 1 | lieksa
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | fernandez
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 1 | srednekolymsk
# Processing Record 17 of Set 1 | camabatela
# Processing Record 18 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | muyezerskiy
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | pombia
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | ust-koksa
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | iqaluit
# Processing Record 32 of Set 1 | san cristobal
# Processing Record 33 of Set 1 | vanimo
# Processing Record 34 of Set 1 | mackay
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | acajutla
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | mackenzie
# Processing Record 42 of Set 1 | airai
# Processing Record 43 of Set 1 | asheville
# Processing Record 44 of Set 1 | mount gambier
# Processing Record 45 of Set 1 | afgoye
# City not found. Skipping...
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | timbiqui
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | agadir
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | high level
# Processing Record 5 of Set 2 | huarmey
# Processing Record 6 of Set 2 | nome
# Processing Record 7 of Set 2 | mount isa
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | sorada
# Processing Record 11 of Set 2 | dingle
# Processing Record 12 of Set 2 | asfi
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | merauke
# Processing Record 15 of Set 2 | ilulissat
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | berlevag
# Processing Record 19 of Set 2 | pyapon
# Processing Record 20 of Set 2 | punta arenas
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | metro
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | pangnirtung
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | migori
# Processing Record 28 of Set 2 | yeniseysk
# Processing Record 29 of Set 2 | saldanha
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | kahului
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | ciudad bolivar
# Processing Record 34 of Set 2 | broken hill
# Processing Record 35 of Set 2 | madang
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | praia da vitoria
# Processing Record 38 of Set 2 | bethanien
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | laguna
# Processing Record 41 of Set 2 | rosario
# Processing Record 42 of Set 2 | guerrero negro
# Processing Record 43 of Set 2 | anloga
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | yarada
# Processing Record 46 of Set 2 | palaikastron
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | suffolk
# Processing Record 49 of Set 2 | surgut
# Processing Record 50 of Set 2 | arawa
# Processing Record 1 of Set 3 | termiz
# Processing Record 2 of Set 3 | pangai
# Processing Record 3 of Set 3 | vila franca do campo
# Processing Record 4 of Set 3 | mpanda
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | lata
# Processing Record 7 of Set 3 | lena
# Processing Record 8 of Set 3 | gilgit
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | tuatapere
# Processing Record 12 of Set 3 | cayenne
# Processing Record 13 of Set 3 | guarapari
# Processing Record 14 of Set 3 | namatanai
# Processing Record 15 of Set 3 | flin flon
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | altoona
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | zaysan
# Processing Record 24 of Set 3 | shahi
# Processing Record 25 of Set 3 | kutum
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | leningradskiy
# Processing Record 30 of Set 3 | nouadhibou
# Processing Record 31 of Set 3 | la ronge
# Processing Record 32 of Set 3 | constitucion
# Processing Record 33 of Set 3 | vila
# Processing Record 34 of Set 3 | port blair
# Processing Record 35 of Set 3 | jibuti
# Processing Record 36 of Set 3 | palmer
# Processing Record 37 of Set 3 | bilma
# Processing Record 38 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 3 | alice springs
# Processing Record 40 of Set 3 | east london
# Processing Record 41 of Set 3 | mizdah
# Processing Record 42 of Set 3 | lakselv
# Processing Record 43 of Set 3 | lagoa
# Processing Record 44 of Set 3 | kamaishi
# Processing Record 45 of Set 3 | vicuna
# Processing Record 46 of Set 3 | soe
# Processing Record 47 of Set 3 | asau
# Processing Record 48 of Set 3 | grand gaube
# Processing Record 49 of Set 3 | chuy
# Processing Record 50 of Set 3 | the valley
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | port shepstone
# Processing Record 3 of Set 4 | touros
# Processing Record 4 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 5 of Set 4 | cape town
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | manavalakurichi
# Processing Record 8 of Set 4 | plettenberg bay
# Processing Record 9 of Set 4 | bandarbeyla
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | awallan
# Processing Record 13 of Set 4 | opuwo
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | jardim
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | jagadhri
# Processing Record 18 of Set 4 | harlingen
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | lahijan
# Processing Record 21 of Set 4 | shubarkuduk
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | kraskino
# Processing Record 24 of Set 4 | santiago del estero
# Processing Record 25 of Set 4 | abu samrah
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | eatonton
# Processing Record 28 of Set 4 | aranos
# Processing Record 29 of Set 4 | sulangan
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | kijang
# Processing Record 32 of Set 4 | faanui
# Processing Record 33 of Set 4 | half moon bay
# Processing Record 34 of Set 4 | norman wells
# Processing Record 35 of Set 4 | chapais
# Processing Record 36 of Set 4 | sorland
# Processing Record 37 of Set 4 | mayor pablo lagerenza
# Processing Record 38 of Set 4 | la plaine
# Processing Record 39 of Set 4 | mezen
# Processing Record 40 of Set 4 | roscommon
# Processing Record 41 of Set 4 | ahipara
# Processing Record 42 of Set 4 | diamantino
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | cortes
# Processing Record 45 of Set 4 | nurota
# Processing Record 46 of Set 4 | cravo norte
# Processing Record 47 of Set 4 | hanzhong
# Processing Record 48 of Set 4 | narsaq
# Processing Record 49 of Set 4 | georgiyevka
# Processing Record 50 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | san vicente
# Processing Record 3 of Set 5 | salekhard
# Processing Record 4 of Set 5 | nombre de dios
# Processing Record 5 of Set 5 | mkushi
# Processing Record 6 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | sao raimundo das mangabeiras
# Processing Record 9 of Set 5 | xining
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | batemans bay
# Processing Record 12 of Set 5 | chivay
# Processing Record 13 of Set 5 | nueve de julio
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | jacksonville
# Processing Record 16 of Set 5 | vung tau
# Processing Record 17 of Set 5 | abnub
# Processing Record 18 of Set 5 | khasan
# Processing Record 19 of Set 5 | katobu
# Processing Record 20 of Set 5 | jimma
# Processing Record 21 of Set 5 | uvinza
# Processing Record 22 of Set 5 | tessalit
# Processing Record 23 of Set 5 | neiafu
# Processing Record 24 of Set 5 | namibe
# Processing Record 25 of Set 5 | yar-sale
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | olga
# Processing Record 28 of Set 5 | tetiyiv
# Processing Record 29 of Set 5 | sur
# Processing Record 30 of Set 5 | rawson
# Processing Record 31 of Set 5 | port charlotte
# Processing Record 32 of Set 5 | baiyin
# Processing Record 33 of Set 5 | grandview
# Processing Record 34 of Set 5 | saint-augustin
# Processing Record 35 of Set 5 | vancouver
# Processing Record 36 of Set 5 | turkistan
# Processing Record 37 of Set 5 | pacific grove
# Processing Record 38 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | genc
# Processing Record 41 of Set 5 | fort nelson
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | el wasta
# City not found. Skipping...
# Processing Record 44 of Set 5 | champua
# Processing Record 45 of Set 5 | srivardhan
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | tecpan
# Processing Record 48 of Set 5 | pingliang
# Processing Record 49 of Set 5 | neryungri
# Processing Record 50 of Set 5 | yerbogachen
# Processing Record 1 of Set 6 | husavik
# Processing Record 2 of Set 6 | benguela
# Processing Record 3 of Set 6 | murgab
# Processing Record 4 of Set 6 | flinders
# Processing Record 5 of Set 6 | vila velha
# Processing Record 6 of Set 6 | bilibino
# Processing Record 7 of Set 6 | atambua
# Processing Record 8 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 6 | lamu
# Processing Record 10 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 6 | ambunti
# Processing Record 13 of Set 6 | pundaguitan
# Processing Record 14 of Set 6 | westminster
# Processing Record 15 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 6 | agustin codazzi
# Processing Record 17 of Set 6 | rocha
# Processing Record 18 of Set 6 | bolobo
# Processing Record 19 of Set 6 | umea
# Processing Record 20 of Set 6 | eyl
# Processing Record 21 of Set 6 | goreloye
# Processing Record 22 of Set 6 | nhulunbuy
# Processing Record 23 of Set 6 | tanout
# Processing Record 24 of Set 6 | gopalur
# Processing Record 25 of Set 6 | honiara
# Processing Record 26 of Set 6 | saint anthony
# Processing Record 27 of Set 6 | tezu
# Processing Record 28 of Set 6 | papar
# Processing Record 29 of Set 6 | shar
# Processing Record 30 of Set 6 | shelburne
# Processing Record 31 of Set 6 | upernavik
# Processing Record 32 of Set 6 | talcahuano
# Processing Record 33 of Set 6 | north mankato
# Processing Record 34 of Set 6 | yushan
# Processing Record 35 of Set 6 | visby
# Processing Record 36 of Set 6 | mogocha
# Processing Record 37 of Set 6 | havre-saint-pierre
# Processing Record 38 of Set 6 | seminole
# Processing Record 39 of Set 6 | marawi
# Processing Record 40 of Set 6 | natitingou
# Processing Record 41 of Set 6 | bonthe
# Processing Record 42 of Set 6 | high river
# Processing Record 43 of Set 6 | hobyo
# Processing Record 44 of Set 6 | aquidauana
# Processing Record 45 of Set 6 | rudnogorsk
# Processing Record 46 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 6 | ampanihy
# Processing Record 48 of Set 6 | maxixe
# Processing Record 49 of Set 6 | cabo san lucas
# Processing Record 50 of Set 6 | sembakung
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | uvalde
# Processing Record 3 of Set 7 | isla mujeres
# Processing Record 4 of Set 7 | lompoc
# Processing Record 5 of Set 7 | libres
# Processing Record 6 of Set 7 | dong hoi
# Processing Record 7 of Set 7 | durant
# Processing Record 8 of Set 7 | iwanai
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 7 | cooma
# Processing Record 12 of Set 7 | hokitika
# Processing Record 13 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 7 | biak
# Processing Record 16 of Set 7 | luderitz
# Processing Record 17 of Set 7 | zeya
# Processing Record 18 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 7 | polovinnoye
# Processing Record 20 of Set 7 | dukat
# Processing Record 21 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 22 of Set 7 | sao caetano de odivelas
# Processing Record 23 of Set 7 | necochea
# Processing Record 24 of Set 7 | benghazi
# Processing Record 25 of Set 7 | evensk
# Processing Record 26 of Set 7 | sao goncalo do sapucai
# Processing Record 27 of Set 7 | kruisfontein
# Processing Record 28 of Set 7 | salalah
# Processing Record 29 of Set 7 | georgiyevskoye
# Processing Record 30 of Set 7 | fort william
# Processing Record 31 of Set 7 | saint-joseph
# Processing Record 32 of Set 7 | monte patria
# Processing Record 33 of Set 7 | baoshan
# Processing Record 34 of Set 7 | shimoda
# Processing Record 35 of Set 7 | xingcheng
# Processing Record 36 of Set 7 | vanavara
# Processing Record 37 of Set 7 | pisco
# Processing Record 38 of Set 7 | abu dhabi
# Processing Record 39 of Set 7 | agucadoura
# Processing Record 40 of Set 7 | peleduy
# Processing Record 41 of Set 7 | vestmannaeyjar
# Processing Record 42 of Set 7 | kathmandu
# Processing Record 43 of Set 7 | vao
# Processing Record 44 of Set 7 | san patricio
# Processing Record 45 of Set 7 | henties bay
# Processing Record 46 of Set 7 | shuangyashan
# Processing Record 47 of Set 7 | masvingo
# Processing Record 48 of Set 7 | nisia floresta
# Processing Record 49 of Set 7 | buala
# Processing Record 50 of Set 7 | marsh harbour
# Processing Record 1 of Set 8 | boa vista
# Processing Record 2 of Set 8 | los llanos de aridane
# Processing Record 3 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 8 | caucaia
# Processing Record 5 of Set 8 | portland
# Processing Record 6 of Set 8 | bouca
# Processing Record 7 of Set 8 | urumqi
# Processing Record 8 of Set 8 | mosquera
# Processing Record 9 of Set 8 | male
# Processing Record 10 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 8 | rantepao
# Processing Record 12 of Set 8 | labuhan
# Processing Record 13 of Set 8 | sao filipe
# Processing Record 14 of Set 8 | ust-omchug
# Processing Record 15 of Set 8 | sitka
# Processing Record 16 of Set 8 | sioux lookout
# Processing Record 17 of Set 8 | ndele
# Processing Record 18 of Set 8 | xinyang
# Processing Record 19 of Set 8 | manaure
# Processing Record 20 of Set 8 | noyabrsk
# Processing Record 21 of Set 8 | rudbar
# Processing Record 22 of Set 8 | zhigalovo
# Processing Record 23 of Set 8 | faya
# Processing Record 24 of Set 8 | negombo
# Processing Record 25 of Set 8 | athabasca
# Processing Record 26 of Set 8 | prince rupert
# Processing Record 27 of Set 8 | kununurra
# Processing Record 28 of Set 8 | minab
# Processing Record 29 of Set 8 | killybegs
# Processing Record 30 of Set 8 | adeje
# Processing Record 31 of Set 8 | nuwara eliya
# Processing Record 32 of Set 8 | sisimiut
# Processing Record 33 of Set 8 | cururupu
# Processing Record 34 of Set 8 | pangody
# Processing Record 35 of Set 8 | cabedelo
# Processing Record 36 of Set 8 | prabumulih
# Processing Record 37 of Set 8 | yulara
# Processing Record 38 of Set 8 | umarkot
# Processing Record 39 of Set 8 | port lincoln
# Processing Record 40 of Set 8 | manggar
# Processing Record 41 of Set 8 | boyolangu
# Processing Record 42 of Set 8 | humboldt
# Processing Record 43 of Set 8 | bud
# Processing Record 44 of Set 8 | fairbanks
# Processing Record 45 of Set 8 | bac lieu
# Processing Record 46 of Set 8 | renqiu
# Processing Record 47 of Set 8 | mandalay
# Processing Record 48 of Set 8 | riwaka
# Processing Record 49 of Set 8 | krasna lipa
# Processing Record 50 of Set 8 | luanda
# Processing Record 1 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 2 of Set 9 | isabela
# Processing Record 3 of Set 9 | kurilsk
# Processing Record 4 of Set 9 | grindavik
# Processing Record 5 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 9 | dwarka
# Processing Record 7 of Set 9 | andra
# Processing Record 8 of Set 9 | batagay
# Processing Record 9 of Set 9 | bakel
# Processing Record 10 of Set 9 | gigmoto
# Processing Record 11 of Set 9 | grants
# Processing Record 12 of Set 9 | dombarovskiy
# Processing Record 13 of Set 9 | durres
# Processing Record 14 of Set 9 | bucerias
# Processing Record 15 of Set 9 | yenagoa
# Processing Record 16 of Set 9 | le vauclin
# Processing Record 17 of Set 9 | ambikapur
# Processing Record 18 of Set 9 | rapid valley
# Processing Record 19 of Set 9 | nalut
# Processing Record 20 of Set 9 | varnamo
# Processing Record 21 of Set 9 | olinda
# Processing Record 22 of Set 9 | jurm
# Processing Record 23 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 9 | beringovskiy
# Processing Record 25 of Set 9 | podgorica
# Processing Record 26 of Set 9 | kangasala
# Processing Record 27 of Set 9 | zhezkazgan
# Processing Record 28 of Set 9 | willowmore
# Processing Record 29 of Set 9 | wencheng
# Processing Record 30 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 9 | paulo afonso
# Processing Record 32 of Set 9 | jos
# Processing Record 33 of Set 9 | broome
# Processing Record 34 of Set 9 | ostrovnoy
# Processing Record 35 of Set 9 | hami
# Processing Record 36 of Set 9 | belyy yar
# Processing Record 37 of Set 9 | ciudad guayana
# Processing Record 38 of Set 9 | rio grande city
# Processing Record 39 of Set 9 | bayanday
# Processing Record 40 of Set 9 | atlantic city
# Processing Record 41 of Set 9 | clonakilty
# Processing Record 42 of Set 9 | pangoa
# Processing Record 43 of Set 9 | andilamena
# Processing Record 44 of Set 9 | atar
# Processing Record 45 of Set 9 | ventspils
# Processing Record 46 of Set 9 | mapastepec
# Processing Record 47 of Set 9 | freeport
# Processing Record 48 of Set 9 | qui nhon
# Processing Record 49 of Set 9 | irtyshskiy
# Processing Record 50 of Set 9 | esperance
# Processing Record 1 of Set 10 | baltimore
# Processing Record 2 of Set 10 | bengkulu
# Processing Record 3 of Set 10 | phuket
# Processing Record 4 of Set 10 | buta
# Processing Record 5 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 6 of Set 10 | batticaloa
# Processing Record 7 of Set 10 | vangaindrano
# Processing Record 8 of Set 10 | wapakoneta
# Processing Record 9 of Set 10 | mayo
# Processing Record 10 of Set 10 | botwood
# Processing Record 11 of Set 10 | wanning
# Processing Record 12 of Set 10 | kazerun
# Processing Record 13 of Set 10 | alta floresta
# Processing Record 14 of Set 10 | cockburn town
# Processing Record 15 of Set 10 | tiznit
# Processing Record 16 of Set 10 | bongandanga
# Processing Record 17 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 18 of Set 10 | podkletnoye
# Processing Record 19 of Set 10 | oda
# Processing Record 20 of Set 10 | richards bay
# Processing Record 21 of Set 10 | zubtsov
# Processing Record 22 of Set 10 | matara
# Processing Record 23 of Set 10 | abu zabad
# Processing Record 24 of Set 10 | oranjemund
# Processing Record 25 of Set 10 | kulhudhuffushi
# Processing Record 26 of Set 10 | welkom
# Processing Record 27 of Set 10 | theog
# Processing Record 28 of Set 10 | kumta
# Processing Record 29 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 10 | karratha
# Processing Record 31 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 10 | ordu
# Processing Record 33 of Set 10 | turinsk
# Processing Record 34 of Set 10 | buraydah
# Processing Record 35 of Set 10 | bathsheba
# Processing Record 36 of Set 10 | belmonte
# Processing Record 37 of Set 10 | union city
# Processing Record 38 of Set 10 | naze
# Processing Record 39 of Set 10 | la paz
# Processing Record 40 of Set 10 | lorengau
# Processing Record 41 of Set 10 | komsomolskiy
# Processing Record 42 of Set 10 | timra
# Processing Record 43 of Set 10 | solnechnyy
# Processing Record 44 of Set 10 | tambacounda
# Processing Record 45 of Set 10 | valentin gomez farias
# Processing Record 46 of Set 10 | aykhal
# Processing Record 47 of Set 10 | lake charles
# Processing Record 48 of Set 10 | isangel
# Processing Record 49 of Set 10 | nicoya
# Processing Record 50 of Set 10 | linxia
# Processing Record 1 of Set 11 | alexandria
# Processing Record 2 of Set 11 | adrar
# Processing Record 3 of Set 11 | trinidad
# Processing Record 4 of Set 11 | buchanan
# Processing Record 5 of Set 11 | booue
# Processing Record 6 of Set 11 | santa elena
# Processing Record 7 of Set 11 | ostersund
# Processing Record 8 of Set 11 | barabai
# Processing Record 9 of Set 11 | buin
# Processing Record 10 of Set 11 | plouzane
# Processing Record 11 of Set 11 | jalingo
# Processing Record 12 of Set 11 | shetpe
# Processing Record 13 of Set 11 | dongsheng
# Processing Record 14 of Set 11 | codrington
# Processing Record 15 of Set 11 | hailar
# Processing Record 16 of Set 11 | tonekabon
# Processing Record 17 of Set 11 | coquimbo
# Processing Record 18 of Set 11 | penzance
# Processing Record 19 of Set 11 | nemuro
# Processing Record 20 of Set 11 | sault sainte marie
# Processing Record 21 of Set 11 | hualmay
# Processing Record 22 of Set 11 | salima
# Processing Record 23 of Set 11 | andros town
# Processing Record 24 of Set 11 | rio pardo
# Processing Record 25 of Set 11 | diveyevo
# Processing Record 26 of Set 11 | mehamn
# Processing Record 27 of Set 11 | port macquarie
# Processing Record 28 of Set 11 | yambio
# Processing Record 29 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 11 | hambantota
# Processing Record 31 of Set 11 | ishigaki
# Processing Record 32 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 11 | minsk
# Processing Record 34 of Set 11 | ravar
# Processing Record 35 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 11 | coihaique
# Processing Record 37 of Set 11 | novyy urengoy
# Processing Record 38 of Set 11 | samarai
# Processing Record 39 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 11 | somerset west
# Processing Record 41 of Set 11 | poum
# Processing Record 42 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 43 of Set 11 | port hardy
# Processing Record 44 of Set 11 | makakilo city
# Processing Record 45 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 11 | edendale
# Processing Record 47 of Set 11 | sobolevo
# Processing Record 48 of Set 11 | zhigansk
# Processing Record 49 of Set 11 | yatou
# Processing Record 50 of Set 11 | juneau
# Processing Record 1 of Set 12 | kawalu
# Processing Record 2 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 3 of Set 12 | anadyr
# Processing Record 4 of Set 12 | san joaquin
# Processing Record 5 of Set 12 | northam
# Processing Record 6 of Set 12 | puerto escondido
# Processing Record 7 of Set 12 | san policarpo
# Processing Record 8 of Set 12 | majene
# Processing Record 9 of Set 12 | peniche
# Processing Record 10 of Set 12 | beyneu
# Processing Record 11 of Set 12 | yaan
# Processing Record 12 of Set 12 | mpraeso
# Processing Record 13 of Set 12 | nishihara
# Processing Record 14 of Set 12 | columbus
# Processing Record 15 of Set 12 | patiya
# Processing Record 16 of Set 12 | sao joao da barra
# Processing Record 17 of Set 12 | kozhva
# Processing Record 18 of Set 12 | langenhagen
# Processing Record 19 of Set 12 | santa isabel do rio negro
# Processing Record 20 of Set 12 | krasnoselkup
# Processing Record 21 of Set 12 | fuglebjerg
# Processing Record 22 of Set 12 | paita
# Processing Record 23 of Set 12 | fukue
# Processing Record 24 of Set 12 | canarana
# Processing Record 25 of Set 12 | xanlar
# Processing Record 26 of Set 12 | berck
# Processing Record 27 of Set 12 | sinnamary
# Processing Record 28 of Set 12 | dourados
# Processing Record 29 of Set 12 | aksu
# Processing Record 30 of Set 12 | maputo
# Processing Record 31 of Set 12 | havelock
# Processing Record 32 of Set 12 | catamarca
# Processing Record 33 of Set 12 | saryg-sep
# Processing Record 34 of Set 12 | bandipur
# Processing Record 35 of Set 12 | teya
# Processing Record 36 of Set 12 | raudeberg
# Processing Record 37 of Set 12 | oparino
# Processing Record 38 of Set 12 | rupert
# Processing Record 39 of Set 12 | glodeni
# Processing Record 40 of Set 12 | camocim
# Processing Record 41 of Set 12 | ratnagiri
# Processing Record 42 of Set 12 | acapulco
# Processing Record 43 of Set 12 | voh
# Processing Record 44 of Set 12 | yellandu
# Processing Record 45 of Set 12 | naziya
# Processing Record 46 of Set 12 | pedernales
# Processing Record 47 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 12 | brownwood
# Processing Record 49 of Set 12 | ayan
# Processing Record 50 of Set 12 | padang
# Processing Record 1 of Set 13 | paamiut
# Processing Record 2 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 13 | nambour
# Processing Record 4 of Set 13 | pinega
# Processing Record 5 of Set 13 | rio tuba
# Processing Record 6 of Set 13 | baculin
# Processing Record 7 of Set 13 | kholodnyy
# Processing Record 8 of Set 13 | jiangyou
# Processing Record 9 of Set 13 | nagato
# Processing Record 10 of Set 13 | alamos
# Processing Record 11 of Set 13 | muroto
# Processing Record 12 of Set 13 | chamba
# Processing Record 13 of Set 13 | phnum penh
# City not found. Skipping...
# Processing Record 14 of Set 13 | sistranda
# Processing Record 15 of Set 13 | lubao
# Processing Record 16 of Set 13 | svetlogorsk
# Processing Record 17 of Set 13 | susaki
# Processing Record 18 of Set 13 | kieta
# Processing Record 19 of Set 13 | muhos
# Processing Record 20 of Set 13 | aljezur
# Processing Record 21 of Set 13 | trelew
# Processing Record 22 of Set 13 | lop buri
# Processing Record 23 of Set 13 | bousso
# Processing Record 24 of Set 13 | eresos
# Processing Record 25 of Set 13 | hammerfest
# Processing Record 26 of Set 13 | hovd
# Processing Record 27 of Set 13 | champerico
# Processing Record 28 of Set 13 | arman
# Processing Record 29 of Set 13 | kedrovyy
# Processing Record 30 of Set 13 | woodbury
# Processing Record 31 of Set 13 | daura
# Processing Record 32 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 33 of Set 13 | afikpo
# Processing Record 34 of Set 13 | lipari
# Processing Record 35 of Set 13 | cocobeach
# Processing Record 36 of Set 13 | muisne
# Processing Record 37 of Set 13 | gisborne
# Processing Record 38 of Set 13 | paysandu
# Processing Record 39 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 13 | harper
# Processing Record 41 of Set 13 | mbaiki
# Processing Record 42 of Set 13 | assiniboia
# Processing Record 43 of Set 13 | mumford
# Processing Record 44 of Set 13 | meulaboh
# Processing Record 45 of Set 13 | vilhena
# Processing Record 46 of Set 13 | caravelas
# Processing Record 47 of Set 13 | tautira
# Processing Record 48 of Set 13 | rutul
# Processing Record 49 of Set 13 | phalaborwa
# Processing Record 50 of Set 13 | gat
# Processing Record 1 of Set 14 | muli
# Processing Record 2 of Set 14 | katsuura
# Processing Record 3 of Set 14 | inirida
# Processing Record 4 of Set 14 | moree
# Processing Record 5 of Set 14 | jalu
# Processing Record 6 of Set 14 | saint-pierre
# Processing Record 7 of Set 14 | cabinda
# Processing Record 8 of Set 14 | calamar
# Processing Record 9 of Set 14 | namwala
# Processing Record 10 of Set 14 | junin
# Processing Record 11 of Set 14 | laredo
# Processing Record 12 of Set 14 | lima
# Processing Record 13 of Set 14 | topolevo
# Processing Record 14 of Set 14 | san juan evangelista
# Processing Record 15 of Set 14 | sinazongwe
# Processing Record 16 of Set 14 | zaragoza
# Processing Record 17 of Set 14 | puerto narino
# Processing Record 18 of Set 14 | sena madureira
# Processing Record 19 of Set 14 | mgandu
# Processing Record 20 of Set 14 | zlatoustovsk
# City not found. Skipping...
# Processing Record 21 of Set 14 | beni
# Processing Record 22 of Set 14 | kalmunai
# Processing Record 23 of Set 14 | tilichiki
# Processing Record 24 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 25 of Set 14 | syracuse
# Processing Record 26 of Set 14 | lazurne
# Processing Record 27 of Set 14 | richard toll
# City not found. Skipping...
# Processing Record 28 of Set 14 | sibolga
# Processing Record 29 of Set 14 | comodoro rivadavia
# Processing Record 30 of Set 14 | walvis bay
# Processing Record 31 of Set 14 | shahrud
# Processing Record 32 of Set 14 | erzin
# Processing Record 33 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 34 of Set 14 | outjo
# Processing Record 35 of Set 14 | dorna
# Processing Record 36 of Set 14 | elizabeth city
# Processing Record 37 of Set 14 | coruripe
# Processing Record 38 of Set 14 | kalaleh
# Processing Record 39 of Set 14 | kloulklubed
# Processing Record 40 of Set 14 | panzhihua
# Processing Record 41 of Set 14 | helena
# Processing Record 42 of Set 14 | casalmaggiore
# Processing Record 43 of Set 14 | kailua
# Processing Record 44 of Set 14 | bosaso
# Processing Record 45 of Set 14 | gedo
# Processing Record 46 of Set 14 | kimbe
# Processing Record 47 of Set 14 | liusha
# Processing Record 48 of Set 14 | amapa
# Processing Record 49 of Set 14 | okoneshnikovo
# Processing Record 50 of Set 14 | araouane
# Processing Record 1 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 15 | oriximina
# Processing Record 3 of Set 15 | hofn
# Processing Record 4 of Set 15 | tahta
# Processing Record 5 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 15 | costinesti
# Processing Record 7 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 15 | pahrump
# Processing Record 9 of Set 15 | nabire
# Processing Record 10 of Set 15 | tatebayashi
# Processing Record 11 of Set 15 | ugoofaaru
# Processing Record 12 of Set 15 | sovetskaya gavan
# Processing Record 13 of Set 15 | tazmalt
# Processing Record 14 of Set 15 | ozernovskiy
# Processing Record 15 of Set 15 | kobayashi
# Processing Record 16 of Set 15 | hatillo
# Processing Record 17 of Set 15 | filingue
# Processing Record 18 of Set 15 | ponazyrevo
# Processing Record 19 of Set 15 | andenes
# Processing Record 20 of Set 15 | leshukonskoye
# Processing Record 21 of Set 15 | moissala
# Processing Record 22 of Set 15 | najran
# Processing Record 23 of Set 15 | novaci
# Processing Record 24 of Set 15 | general roca
# Processing Record 25 of Set 15 | kulu
# Processing Record 26 of Set 15 | itoman
# Processing Record 27 of Set 15 | djougou
# Processing Record 28 of Set 15 | zhanaozen
# Processing Record 29 of Set 15 | rio grande
# Processing Record 30 of Set 15 | paramonga
# Processing Record 31 of Set 15 | olafsvik
# Processing Record 32 of Set 15 | kenai
# Processing Record 33 of Set 15 | chifeng
# Processing Record 34 of Set 15 | margate
# Processing Record 35 of Set 15 | inzhavino
# Processing Record 36 of Set 15 | golden
# Processing Record 37 of Set 15 | calca
# Processing Record 38 of Set 15 | moses lake
# Processing Record 39 of Set 15 | nantucket
# Processing Record 40 of Set 15 | bocaranga
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Pasvalys      LT  56.0594   24.4036     67.32        96          64
# 1          Atuona      PF  -9.8000 -139.0333     77.83        71           1
# 2  Ribeira Grande      PT  38.5167  -28.7000     72.01        85          55
# 3         Talnakh      RU  69.4865   88.3972     61.65        86          96
# 4     New Norfolk      AU -42.7826  147.0587     55.92        63          53
# 5          Avarua      CK -21.2078 -159.7750     77.05        65          21
# 6        Teguldet      RU  57.3064   88.1667     61.92        63          92
# 7          Lieksa      FI  63.3167   30.0167     60.94        89          51
# 8    Ponta Do Sol      PT  32.6667  -17.1000     70.72        77           3
# 9       Fernandez      AR -27.9204  -63.8935     46.99        32           4
#
#    Wind Speed Current Description
# 0        5.82       broken clouds
# 1       17.92           clear sky
# 2        8.61       broken clouds
# 3        4.45          light rain
# 4        5.01          light rain
# 5        4.61          few clouds
# 6        2.37     overcast clouds
# 7        3.74       broken clouds
# 8        3.98           clear sky
# 9        3.62           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
